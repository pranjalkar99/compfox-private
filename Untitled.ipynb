# %%
import pandas as pd

# %%
display("Labor codes/export_All-Labor-Codes_2022-10-12_20-25-01.csv")
# Out:
# 'Labor codes/export_All-Labor-Codes_2022-10-12_20-25-01.csv'

# %%
data = pd.read_csv('export_All-Labor-Codes_2022-10-12_20-25-01.csv')

# %%
data.head()
# Out:
#    Code                                        Description  \
# 0  50.5  One of the functions of the Department of Indu...
# 1  50.6  The Department of Industrial Relations may ass...
# 2    50  There is in the Labor and Workforce Developmen...
# 3  50.8  The department shall develop a long range prog...
# 4  50.7  (a) The Department of Industrial Relations is ...
#
#                                         Search Field  \
# 0  50.5 One of the functions of the Department of...
# 1  50.6 The Department of Industrial Relations ma...
# 2  50 There is in the Labor and Workforce Develop...
# 3  50.8 The department shall develop a long range...
# 4  50.7 (a) The Department of Industrial Relation...
#
#                                              Subtext         Creation Date  \
# 0                   (Added by Stats. 1939, Ch. 276.)  Jun 21, 2022 6:43 am
# 1                    (Added by Stats. 1953, Ch. 31.)  Jun 21, 2022 6:43 am
# ...

# %%
Code = data["Code"]

# %%
Code.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       50.5
# 1       50.6
# 2         50
# 3       50.8
# 4       50.7
#         ...
# 2440    9102
# 2441    9103
# 2442    9110
# 2443    9101
# 2444    9104
# Name: Code, Length: 2445, dtype: object>

# %%
code_list = []

# %%
for i in Code:
    code_list.append(i)

# %%
print(code_list)
# Out:
# ['50.5', '50.6', '50', '50.8', '50.7', '54', '50.9', '52', '51', '53', '54.5', '55', '57.5', '57', '59', '60.5', '58', '57.1', '60', '56', '60.9', '60.6', '60.7', '60.8', '62.8', '62.6', '63', '62', '62.5', '61', '64', '64.5', '66', '67', '71', '73', '72', '70.1', '74', '70', '75', '76', '80', '78', '81', '77.7', '77.5', '77', '77.8', '79', '88', '82', '83', '89', '87', '90', '90.3', '89.5', '90.2', '90.5', '90.7', '90.6', '91', '93', '94', '92', '96', '96.1', '95', '96.3', '96.5', '97', '96.6', '96.8', '96.7', '98', '98.3', '98.1', '98.2', '98.6', '98.7', '98.5', '98.74', '98.4', '98.75', '98.8', '101', '99', '100', '100.5', '98.9', '101.5', '98.1', '102', '104', '103', '106', '107.5', '107', '105', '108.5', '108', '108.2', '110', '108.4', '108.3', '111', '112', '115', '113', '121', '120', '122', '119', '116', '117', '126', '123.3', '127', '123.7', '123.6', '125', '123', '124', '123.5', '127.1', '128', '129', '129.5', '130', '132a', '133', '134', '132', '138.1', '131', '135', '138',
# ...

# %%
a = '7680'

# %%
if a in code_list:
    print('Yes')
else:
    print('No')
# Out:
# Yes
